# %%
import sys
import os
sys.path.append('../')

# %%
from simulation.farm_env import FarmEnv
from simulation.env_wrapper import MultiAgentActionWrapper
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
#### Configuration: SET THE CROP AND MODEL NAME HERE ---

# -- CROP TO TRAIN --
# Change this to "Rice" or "Sugarcane" to train those models.
CROP_TYPE = "Wheat" 
# Corresponding location for weather data
# For Rice: 22.5726 (Kolkata), For Sugarcane: 26.8467 (Lucknow)
LATITUDE = 30.9010 # Ludhiana for Wheat
LONGITUDE = 75.8573

# %%
# -- TRAINING PARAMETERS --
# This is our most complex agent. It needs a very long training run to learn
# how to use the new forecast information effectively.
TRAINING_STEPS = 1000000 # 3 Million steps is a good target
MODEL_NAME = f"ppo_PRESCIENT_{CROP_TYPE.upper()}_champion.zip"

# %%
# -- DIRECTORIES --
models_dir = "../models"
logs_dir = f"../logs/prescient_{CROP_TYPE.lower()}_logs/"
os.makedirs(models_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)

# %%
#### Environment Setup ---
print(f"--- Creating PRESCIENT environment for CROP: {CROP_TYPE} at LOC: ({LATITUDE}, {LONGITUDE}) ---")

# Define a function to create the environment.
def make_env():
    # Pass the crop type and location to the environment constructor
    env = FarmEnv(
        crop_type=CROP_TYPE,
        latitude=LATITUDE,
        longitude=LONGITUDE
    ) 
    # The wrapper is essential to handle the multi-action space
    env = MultiAgentActionWrapper(env)
    return env
# Out:
# --- Creating PRESCIENT environment for CROP: Wheat at LOC: (30.901, 75.8573) ---

# %%
# Create the wrapped environment
wrapped_env = make_env()
print("Environment ready for training.")
# Out:
# --- Loading Weather Forecaster Ensemble ---
# Loaded model 1/5 successfully.
# Loaded model 2/5 successfully.
# Loaded model 3/5 successfully.
# Loaded model 4/5 successfully.
# Loaded model 5/5 successfully.
# Stochastic weather forecaster loaded and ready.
# Fetching real weather data for Lat: 30.901, Long: 75.8573 from Open-Meteo...
# Sucessfully fetched and processed real weather data from Open-Meteo.
# Environment ready for training.

# %%
#### Model Definition with a More Powerful Brain ---

# A larger neural network is needed for the new, larger observation space.
# We will use three hidden layers to process the complex forecast data.
policy_kwargs = dict(net_arch=dict(pi=[256, 256, 128], vf=[256, 256, 128]))

# We will use advanced PPO parameters for more stable training.
model = PPO(
    "MlpPolicy",
    wrapped_env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=logs_dir,
    learning_rate=0.0001,
    n_steps=4096,
    batch_size=128,
    gamma=0.99,
    gae_lambda=0.95
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
## Training ---

# Set up a callback to save the model periodically
checkpoint_callback = CheckpointCallback(
  save_freq=100000, # Save a checkpoint every 100,000 steps
  save_path=os.path.join(logs_dir, 'checkpoints'),
  name_prefix=f"prescient_{CROP_TYPE.lower()}_model"
)

# %%
print(f"\n--- Starting PRESCIENT CHAMPION training for {CROP_TYPE} ---")
print(f"Total timesteps: {TRAINING_STEPS}")
print(f"To view live training graphs, open a new terminal, activate your environment,")
print(f"navigate to the project folder, and run:")
print(f"tensorboard --logdir {os.path.abspath(logs_dir)}")
# Out:
# --- Starting PRESCIENT CHAMPION training for Wheat ---
# Total timesteps: 1000000
# To view live training graphs, open a new terminal, activate your environment,
# navigate to the project folder, and run:
# tensorboard --logdir /Users/aadarshraj/Documents/ai_project/digital_twin_farm/logs/prescient_wheat_logs

# %%
# Start the training process
model.learn(
    total_timesteps=TRAINING_STEPS,
    tb_log_name=f"PPO_Prescient_Champion_{CROP_TYPE}",
    callback=checkpoint_callback
)
# Out:
# Logging to ../logs/prescient_wheat_logs/PPO_Prescient_Champion_Wheat_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | 9.71     |
# | time/              |          |
# |    fps             | 162      |
# |    iterations      | 1        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.22        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 2           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012576029 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.0156      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.233       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 1           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.89        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 3           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014850393 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.101       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.296       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.91        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 4           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014214327 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0125      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.239       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.03        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 5           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012272777 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0614      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.22        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 6           |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012129698 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.142       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.305       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 7           |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012195734 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.171       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.277       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.96        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 8           |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011423526 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0782      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.264       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 9.21         |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 9            |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0121755265 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.75        |
# |    explained_variance   | 0.671        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0895       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 0.294        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.19        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 10          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014179546 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.161       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.278       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.97        |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 11          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011567552 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.143       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.282       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 8.84         |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 12           |
# |    time_elapsed         | 304          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0109540615 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.63        |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.113        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 0.212        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.13        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 13          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013230992 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0471      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.37        |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 14          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010757617 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.041       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.278       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 15          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010312617 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.123       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 9.23       |
# | time/                   |            |
# |    fps                  | 160        |
# |    iterations           | 16         |
# |    time_elapsed         | 408        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00989992 |
# |    clip_fraction        | 0.0552     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.723      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0984     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00909   |
# |    value_loss           | 0.22       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.1         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 17          |
# |    time_elapsed         | 435         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009889703 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.133       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.02        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 18          |
# |    time_elapsed         | 463         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011562711 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0458      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.99        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 19          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011205775 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0442      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.22        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 20          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012162926 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0268      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00932    |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 21          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011374749 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0761      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.151       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 9.18         |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 22           |
# |    time_elapsed         | 566          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0111883525 |
# |    clip_fraction        | 0.0745       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.54        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0959       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00995     |
# |    value_loss           | 0.0976       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.15        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 23          |
# |    time_elapsed         | 591         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009962875 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0676      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.12        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 24          |
# |    time_elapsed         | 616         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009642895 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0246      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00819    |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.06        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 25          |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011907984 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0296      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.19        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 26          |
# |    time_elapsed         | 666         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011783252 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0916      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 0.0983      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.46        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 27          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.012668356 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0316      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.0903      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.4         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 28          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012154888 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.000504   |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.0808      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.09        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 29          |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.009822492 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00124    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00988    |
# |    value_loss           | 0.0735      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.26        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 30          |
# |    time_elapsed         | 769         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.010613755 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0256      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.0691      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.27        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 31          |
# |    time_elapsed         | 796         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.009262988 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00111    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 0.082       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.13        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 32          |
# |    time_elapsed         | 823         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.014209872 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0219      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.0527      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.11        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 33          |
# |    time_elapsed         | 848         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.010576302 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00553    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 0.0517      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.25        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 34          |
# |    time_elapsed         | 872         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.011428251 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00307     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.0516      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.11        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 35          |
# |    time_elapsed         | 898         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.009790011 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00787    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 0.0328      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.06        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 36          |
# |    time_elapsed         | 923         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.012113016 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00476    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00972    |
# |    value_loss           | 0.0315      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.3         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 37          |
# |    time_elapsed         | 948         |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.009167593 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0128     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.1         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 38          |
# |    time_elapsed         | 976         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.011300108 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00247    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.0372      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.21        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 39          |
# |    time_elapsed         | 1001        |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.010539945 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0011     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00991    |
# |    value_loss           | 0.0194      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.26        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 40          |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011240967 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00844    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00807    |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 9.33         |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 41           |
# |    time_elapsed         | 1053         |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0069406214 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.000193     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00932     |
# |    value_loss           | 0.0227       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.46        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 42          |
# |    time_elapsed         | 1080        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007911787 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0122     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.19        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 43          |
# |    time_elapsed         | 1106        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.008340795 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0188     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 0.0264      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.91        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 44          |
# |    time_elapsed         | 1132        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.013186938 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00495    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.82        |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 45          |
# |    time_elapsed         | 1159        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.010198079 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00993    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.98        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 46          |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010159934 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0248     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.2         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 47          |
# |    time_elapsed         | 1212        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.012495156 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0264     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 9.22       |
# | time/                   |            |
# |    fps                  | 158        |
# |    iterations           | 48         |
# |    time_elapsed         | 1237       |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.01012209 |
# |    clip_fraction        | 0.0797     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.023     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00969   |
# |    value_loss           | 0.0155     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.96        |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 49          |
# |    time_elapsed         | 1262        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.011304643 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00999    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.95        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 50          |
# |    time_elapsed         | 1287        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.010639428 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00186     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.0134      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.06        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 51          |
# |    time_elapsed         | 1311        |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.013274385 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0121     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.95        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 52          |
# |    time_elapsed         | 1335        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.009134473 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0108     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 0.00932     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 8.8        |
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 53         |
# |    time_elapsed         | 1359       |
# |    total_timesteps      | 217088     |
# | train/                  |            |
# |    approx_kl            | 0.00773132 |
# |    clip_fraction        | 0.0682     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00891   |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00996   |
# |    value_loss           | 0.0114     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.78        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 54          |
# |    time_elapsed         | 1384        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.011116844 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00437    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.009      |
# |    value_loss           | 0.012       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.97        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 55          |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.009980906 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0167     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0102     |
# ...
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 228          |
# |    time_elapsed         | 6567         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0051656645 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0553       |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 0.204        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 229          |
# |    time_elapsed         | 6594         |
# |    total_timesteps      | 937984       |
# | train/                  |              |
# |    approx_kl            | 0.0046855123 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0741       |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00542     |
# |    value_loss           | 0.216        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.6         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 230          |
# |    time_elapsed         | 6620         |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0045980187 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0423       |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.00526     |
# |    value_loss           | 0.154        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 231          |
# |    time_elapsed         | 6646         |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0077109146 |
# |    clip_fraction        | 0.0831       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0582       |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00758     |
# |    value_loss           | 0.144        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 232         |
# |    time_elapsed         | 6672        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.005720352 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.104       |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 0.215       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 233          |
# |    time_elapsed         | 6701         |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0041733757 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0888       |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 234         |
# |    time_elapsed         | 6731        |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.006317638 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.066       |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 235          |
# |    time_elapsed         | 6759         |
# |    total_timesteps      | 962560       |
# | train/                  |              |
# |    approx_kl            | 0.0051246667 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.04         |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 0.0929       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 17.9         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 236          |
# |    time_elapsed         | 6785         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0029080636 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0251       |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 0.0822       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 17.7         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 237          |
# |    time_elapsed         | 6812         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0053236713 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0396       |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.00665     |
# |    value_loss           | 0.104        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 238         |
# |    time_elapsed         | 6839        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.017284548 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0176      |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.0999      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 239         |
# |    time_elapsed         | 6866        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.005155422 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0195      |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 0.0792      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 240          |
# |    time_elapsed         | 6893         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0051156986 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.013        |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00621     |
# |    value_loss           | 0.0829       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 241          |
# |    time_elapsed         | 6921         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0054337643 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0159       |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00514     |
# |    value_loss           | 0.0471       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.7         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 242          |
# |    time_elapsed         | 6949         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0032372074 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.000108     |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 0.0672       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.5         |
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 243          |
# |    time_elapsed         | 6975         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0035479337 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0422       |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 0.0611       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 244         |
# |    time_elapsed         | 7002        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.005748502 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0356      |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 0.057       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 245         |
# |    time_elapsed         | 7031        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.008133588 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.075       |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 0.0754      |
# -----------------------------------------

# %%
### Save the Final Model ---

final_model_path = os.path.join(models_dir, MODEL_NAME)
model.save(final_model_path)

print(f"\n--- PRESCIENT CHAMPION Training Complete! ---")
print(f"The definitive model for {CROP_TYPE} is saved at: {final_model_path}")
# Out:
# --- PRESCIENT CHAMPION Training Complete! ---
# The definitive model for Wheat is saved at: ../models/ppo_PRESCIENT_WHEAT_champion.zip

# %%
# notebooks/train_ultimate_champion.ipynb

import sys
import os
sys.path.append('../')

from simulation.farm_env import FarmEnv
from simulation.env_wrapper import MultiAgentActionWrapper
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback

# --- 1. Configuration: UNCOMMENT THE CROP YOU WANT TO TRAIN ---

# === Option 1: WHEAT in Punjab ===
# CROP_TYPE = "Wheat"
# LATITUDE = 30.9010 # Ludhiana, Punjab
# LONGITUDE = 75.8573
# TRAINING_STEPS = 5_000_000 # More steps recommended for this advanced setup

# === Option 2: RICE in Bihar ===
CROP_TYPE = "Rice"
LATITUDE = 24.7500 # Aurangabad, Bihar
LONGITUDE = 84.3700
TRAINING_STEPS = 5_000_000

# === Option 3: RICE in West Bengal ===
# CROP_TYPE = "Rice"
# LATITUDE = 22.5726 # Kolkata, West Bengal
# LONGITUDE = 88.3639
# TRAINING_STEPS = 5_000_000

# === Option 4: SUGARCANE in Uttar Pradesh ===
# CROP_TYPE = "Sugarcane"
# LATITUDE = 26.8467 # Lucknow, UP
# LONGITUDE = 80.9462
# TRAINING_STEPS = 7_000_000 # Longer season, more training

# ----------------------------------------------------------------

# --- Dynamic Naming based on selected crop ---
MODEL_NAME = f"ppo_ULTIMATE_CHAMPION_{CROP_TYPE.upper()}.zip"
models_dir = "../models"
logs_dir = f"../logs/ultimate_champion_{CROP_TYPE.lower()}_logs/"
os.makedirs(models_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)


# --- 2. Environment Setup with POWER-UP: Vectorization ---
print(f"--- Creating ULTIMATE environment for CROP: {CROP_TYPE} at LOC: ({LATITUDE}, {LONGITUDE}) ---")

# Define the environment creation function with our parameters
env_kwargs = dict(crop_type=CROP_TYPE, latitude=LATITUDE, longitude=LONGITUDE)
# Create 8 parallel environments to accelerate training
num_cpu = 8 
vec_env = make_vec_env(
    FarmEnv, 
    n_envs=num_cpu, 
    env_kwargs=env_kwargs, 
    wrapper_class=MultiAgentActionWrapper
)
print(f"Created {num_cpu} parallel environments for training.")


# --- 3. Model Definition with a More Powerful Brain & POWER-UPs ---

# A large neural network for the complex observations
policy_kwargs = dict(net_arch=dict(pi=[256, 256, 128], vf=[256, 256, 128]))

# POWER-UP: Adaptive Learning Rate
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""
    def func(progress_remaining: float) -> float:
        """Progress_remaining goes from 1.0 to 0.0 over the course of training."""
        return progress_remaining * initial_value
    return func

# POWER-UP: Tuned Hyperparameters for a complex task
model = PPO(
    "MlpPolicy",
    vec_env, # Use the vectorized environment
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=logs_dir,
    learning_rate=linear_schedule(0.0003), # Start at 0.0003 and decrease to 0
    n_steps=2048, # More experience collection before update
    batch_size=64,
    n_epochs=10, # More optimization epochs per update
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01 # Encourage more exploration at the beginning
)

# --- 4. Training ---

# Set up a callback to save the model periodically
# The frequency is now based on total steps, not per-environment steps
checkpoint_callback = CheckpointCallback(
  save_freq=max(100000 // num_cpu, 1),
  save_path=os.path.join(logs_dir, 'checkpoints'),
  name_prefix=f"{CROP_TYPE.lower()}_champion"
)

print(f"\n--- Starting ULTIMATE CHAMPION training for {CROP_TYPE} ---")
print(f"Total timesteps: {TRAINING_STEPS}")
print(f"To view live training graphs, open a new terminal and run:")
print(f"tensorboard --logdir {os.path.abspath(logs_dir)}")

# Start the training process
# Note: total_timesteps is the overall total, it will be divided among the parallel envs
model.learn(
    total_timesteps=TRAINING_STEPS,
    tb_log_name=f"PPO_Ultimate_Champion_{CROP_TYPE}",
    callback=checkpoint_callback
)


# --- 5. Save the Final Model ---
final_model_path = os.path.join(models_dir, MODEL_NAME)
model.save(final_model_path)
# Close the vectorized environment
vec_env.close()

print(f"\n--- ULTIMATE CHAMPION Training Complete! ---")
print(f"The definitive model for {CROP_TYPE} is saved at: {final_model_path}")
