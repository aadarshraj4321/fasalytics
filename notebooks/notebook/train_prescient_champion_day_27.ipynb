# %%
import sys
import os
sys.path.append('../')

# %%
from simulation.farm_env import FarmEnv
from simulation.env_wrapper import MultiAgentActionWrapper
from stable_baselines3 import PPO

# %%
# This is our most complex agent. It needs a long training run to learn
# how to use the new forecast information effectively.
TRAINING_STEPS = 3000000 # 3 Million steps is a good target
MODEL_NAME = "ppo_PRESCIENT_CHAMPION_agent.zip"

models_dir = "../models"
logs_dir = "../logs/prescient_champion_logs/" # A new folder for these specific logs
os.makedirs(models_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)

# %%
print("Creating the FINAL, PRESCIENT environment with weather forecasting...")
# This will initialize your most advanced FarmEnv
base_env = FarmEnv()
# We still need the wrapper for the discrete action space
wrapped_env = MultiAgentActionWrapper(base_env)
print("Environment ready.")
# Out:
# Creating the FINAL, PRESCIENT environment with weather forecasting...
# Weather forecaster loaded and ready.
# Fetching real weather data for Lat: 30.901, Long: 75.8573 from Open-Meteo...
# Sucessfully fetched and processed real weather data from Open-Meteo.
# Environment ready.

# %%
policy_kwargs = dict(net_arch=dict(pi=[256, 256, 128], vf=[256, 256, 128]))

model = PPO(
    "MlpPolicy",
    wrapped_env,
    policy_kwargs=policy_kwargs, # Use the bigger network
    verbose=1,
    tensorboard_log=logs_dir,
    learning_rate=0.0001,
    n_steps=4096,
    batch_size=128,
    gamma=0.99
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
print(f"Starting PRESCIENT CHAMPION training for {TRAINING_STEPS} timesteps...")
print(f"This will be the longest training run. Monitor progress with TensorBoard:")
print(f"tensorboard --logdir {os.path.abspath(logs_dir)}")

model.learn(
    total_timesteps=TRAINING_STEPS,
    tb_log_name="PPO_Prescient_Champion"
)
# Out:
# Starting PRESCIENT CHAMPION training for 3000000 timesteps...
# This will be the longest training run. Monitor progress with TensorBoard:
# tensorboard --logdir /Users/aadarshraj/Documents/ai_project/digital_twin_farm/logs/prescient_champion_logs
# Logging to ../logs/prescient_champion_logs/PPO_Prescient_Champion_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | 14.8     |
# | time/              |          |
# |    fps             | 751      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 4096     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 15.2       |
# | time/                   |            |
# |    fps                  | 709        |
# |    iterations           | 2          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01408809 |
# |    clip_fraction        | 0.0826     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.0188     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.08       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00973   |
# |    value_loss           | 3.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012763373 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.246       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 0.752       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011673821 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.193       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 0.363       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 15.6        |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011605661 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.142       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 0.326       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 15.9       |
# | time/                   |            |
# |    fps                  | 678        |
# |    iterations           | 6          |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00912754 |
# |    clip_fraction        | 0.0619     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.167      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00647   |
# |    value_loss           | 0.346      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 7           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014717169 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.239       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 670         |
# |    iterations           | 8           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013815105 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0701      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.362       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 9           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013110975 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0805      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.365       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 10          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011664912 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.207       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 666         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013001369 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0917      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 12          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012750863 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0734      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.349       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.3       |
# | time/                   |            |
# |    fps                  | 665        |
# |    iterations           | 13         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00826359 |
# |    clip_fraction        | 0.0752     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.71      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.229      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00947   |
# |    value_loss           | 0.346      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 14          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011918163 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.118       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00959    |
# |    value_loss           | 0.288       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 15          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010306218 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.15        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 0.338       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.5       |
# | time/                   |            |
# |    fps                  | 661        |
# |    iterations           | 16         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00802015 |
# |    clip_fraction        | 0.0779     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.4       |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.157      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0113    |
# |    value_loss           | 0.248      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 659         |
# |    iterations           | 17          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011436501 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.2         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 0.292       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.8         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 18           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0071502132 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.142        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00785     |
# |    value_loss           | 0.267        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 632         |
# |    iterations           | 19          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008829036 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.103       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 0.253       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 20          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009563994 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.12        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 0.311       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 21          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009411595 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0832      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 0.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.7       |
# | time/                   |            |
# |    fps                  | 602        |
# |    iterations           | 22         |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01197356 |
# |    clip_fraction        | 0.087      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.19      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0878     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00926   |
# |    value_loss           | 0.25       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.7       |
# | time/                   |            |
# |    fps                  | 600        |
# |    iterations           | 23         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00797854 |
# |    clip_fraction        | 0.0498     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.125      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00477   |
# |    value_loss           | 0.234      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 24          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010752112 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.127       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 0.228       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19.1         |
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 25           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0075335847 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.068        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00652     |
# |    value_loss           | 0.194        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 26          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007920418 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0459      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 0.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 27          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.010605581 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0611      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 0.222       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 28           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0105329305 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.99        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0828       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00899     |
# |    value_loss           | 0.168        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 29          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.008708688 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0789      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0075     |
# |    value_loss           | 0.186       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 30          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.010146157 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.113       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 0.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 31          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.009380593 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0137      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 32          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.005948206 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0231      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00829    |
# |    value_loss           | 0.132       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19.1         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 33           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0076493886 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.076        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00719     |
# |    value_loss           | 0.118        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 34          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.008714855 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0373      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00775    |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 35          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.007863831 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0566      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 0.123       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.8       |
# | time/                   |            |
# |    fps                  | 618        |
# |    iterations           | 36         |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.00649446 |
# |    clip_fraction        | 0.0476     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0569     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.007     |
# |    value_loss           | 0.0905     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 37           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0064223055 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.000937    |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 0.0968       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 19         |
# | time/                   |            |
# |    fps                  | 619        |
# |    iterations           | 38         |
# |    time_elapsed         | 251        |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.01253094 |
# |    clip_fraction        | 0.0739     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.94      |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0192     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00724   |
# |    value_loss           | 0.0776     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 39          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.010126196 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0714      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 0.0782      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 40          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.004973205 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0202      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 0.0971      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 41          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.010142786 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0232      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 0.0833      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 42          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.009241224 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0161      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00944    |
# |    value_loss           | 0.0715      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 43           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0063711954 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0265       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00761     |
# |    value_loss           | 0.0973       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 44          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.007747531 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0179      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 0.0703      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 19.1       |
# | time/                   |            |
# |    fps                  | 612        |
# |    iterations           | 45         |
# |    time_elapsed         | 300        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.01024096 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0348     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00855   |
# |    value_loss           | 0.057      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.9       |
# | time/                   |            |
# |    fps                  | 609        |
# |    iterations           | 46         |
# |    time_elapsed         | 309        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.01011174 |
# |    clip_fraction        | 0.0737     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.94      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0203     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00547   |
# |    value_loss           | 0.0918     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 47          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.011991373 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0336      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 48          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006670536 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0561      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 49          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008148343 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0216      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 0.0556      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 50          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.011557031 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00863     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 0.0555      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 51          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.007894016 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00301    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 0.0574      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 19.1       |
# | time/                   |            |
# |    fps                  | 615        |
# |    iterations           | 52         |
# |    time_elapsed         | 346        |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.00913164 |
# |    clip_fraction        | 0.0628     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.07      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.00325    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00718   |
# |    value_loss           | 0.0475     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 53          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.011948621 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00806     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 0.043       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 18.9       |
# | time/                   |            |
# |    fps                  | 616        |
# |    iterations           | 54         |
# |    time_elapsed         | 358        |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.01073199 |
# |    clip_fraction        | 0.0889     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.06      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.00376    |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0084    |
# |    value_loss           | 0.0448     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 55          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.009982506 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00452    |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 716         |
# |    time_elapsed         | 37636       |
# |    total_timesteps      | 2932736     |
# | train/                  |             |
# |    approx_kl            | 0.008757108 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00296     |
# |    n_updates            | 7150        |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 0.0257      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 717         |
# |    time_elapsed         | 37643       |
# |    total_timesteps      | 2936832     |
# | train/                  |             |
# |    approx_kl            | 0.008903818 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00155     |
# |    n_updates            | 7160        |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.0295      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 718         |
# |    time_elapsed         | 37650       |
# |    total_timesteps      | 2940928     |
# | train/                  |             |
# |    approx_kl            | 0.009482103 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0049      |
# |    n_updates            | 7170        |
# |    policy_gradient_loss | -0.00999    |
# |    value_loss           | 0.0286      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 719          |
# |    time_elapsed         | 37659        |
# |    total_timesteps      | 2945024      |
# | train/                  |              |
# |    approx_kl            | 0.0053389464 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00861     |
# |    n_updates            | 7180         |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 0.0266       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 720         |
# |    time_elapsed         | 37665       |
# |    total_timesteps      | 2949120     |
# | train/                  |             |
# |    approx_kl            | 0.010114834 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0245     |
# |    n_updates            | 7190        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0262      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 721         |
# |    time_elapsed         | 37672       |
# |    total_timesteps      | 2953216     |
# | train/                  |             |
# |    approx_kl            | 0.005658593 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00406     |
# |    n_updates            | 7200        |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 0.0287      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 722         |
# |    time_elapsed         | 37679       |
# |    total_timesteps      | 2957312     |
# | train/                  |             |
# |    approx_kl            | 0.008768592 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.000765   |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | -0.00903    |
# |    value_loss           | 0.0221      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 723          |
# |    time_elapsed         | 37685        |
# |    total_timesteps      | 2961408      |
# | train/                  |              |
# |    approx_kl            | 0.0068670567 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00721     |
# |    n_updates            | 7220         |
# |    policy_gradient_loss | -0.00766     |
# |    value_loss           | 0.0287       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 724         |
# |    time_elapsed         | 37691       |
# |    total_timesteps      | 2965504     |
# | train/                  |             |
# |    approx_kl            | 0.007388735 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0084     |
# |    n_updates            | 7230        |
# |    policy_gradient_loss | -0.00961    |
# |    value_loss           | 0.025       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 725          |
# |    time_elapsed         | 37697        |
# |    total_timesteps      | 2969600      |
# | train/                  |              |
# |    approx_kl            | 0.0072293407 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0116      |
# |    n_updates            | 7240         |
# |    policy_gradient_loss | -0.00765     |
# |    value_loss           | 0.0333       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 726         |
# |    time_elapsed         | 37703       |
# |    total_timesteps      | 2973696     |
# | train/                  |             |
# |    approx_kl            | 0.006495605 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0059     |
# |    n_updates            | 7250        |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 727         |
# |    time_elapsed         | 37710       |
# |    total_timesteps      | 2977792     |
# | train/                  |             |
# |    approx_kl            | 0.008175798 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0391      |
# |    n_updates            | 7260        |
# |    policy_gradient_loss | -0.00698    |
# |    value_loss           | 0.0323      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 728         |
# |    time_elapsed         | 37716       |
# |    total_timesteps      | 2981888     |
# | train/                  |             |
# |    approx_kl            | 0.008010419 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00316    |
# |    n_updates            | 7270        |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 0.0251      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 729         |
# |    time_elapsed         | 37721       |
# |    total_timesteps      | 2985984     |
# | train/                  |             |
# |    approx_kl            | 0.007580152 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00313     |
# |    n_updates            | 7280        |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 730          |
# |    time_elapsed         | 37728        |
# |    total_timesteps      | 2990080      |
# | train/                  |              |
# |    approx_kl            | 0.0067475657 |
# |    clip_fraction        | 0.0746       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0163       |
# |    n_updates            | 7290         |
# |    policy_gradient_loss | -0.00896     |
# |    value_loss           | 0.0298       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 731         |
# |    time_elapsed         | 37734       |
# |    total_timesteps      | 2994176     |
# | train/                  |             |
# |    approx_kl            | 0.011591796 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00552     |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.0255      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.8         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 732          |
# |    time_elapsed         | 37740        |
# |    total_timesteps      | 2998272      |
# | train/                  |              |
# |    approx_kl            | 0.0087222345 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00186      |
# |    n_updates            | 7310         |
# |    policy_gradient_loss | -0.00866     |
# |    value_loss           | 0.0318       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 733          |
# |    time_elapsed         | 37746        |
# |    total_timesteps      | 3002368      |
# | train/                  |              |
# |    approx_kl            | 0.0065162745 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0138      |
# |    n_updates            | 7320         |
# |    policy_gradient_loss | -0.00773     |
# |    value_loss           | 0.0251       |
# ------------------------------------------

# %%
final_model_path = os.path.join(models_dir, MODEL_NAME)
model.save(final_model_path)

print(f"\n--- PRESCIENT CHAMPION Training Complete! ---")
print(f"The definitive prescient champion model is saved at: {final_model_path}")
# Out:
# --- PRESCIENT CHAMPION Training Complete! ---
# The definitive prescient champion model is saved at: ../models/ppo_PRESCIENT_CHAMPION_agent.zip
