# %%
import sys
import os
sys.path.append('../')

# %%
from simulation.farm_env import FarmEnv
from simulation.env_wrapper import MultiAgentActionWrapper
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
TRAINING_STEPS = 1000000 
MODEL_NAME = "ppo_marl_super_agent.zip" # The name for our definitive super-agent

# Define directories for models and TensorBoard logs
models_dir = "../models"
logs_dir = "../logs/marl_logs/" # A dedicated folder for these logs
os.makedirs(models_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)

# %%
print("Creating the base Multi-Agent environment...")
# 1. Create the base environment, which expects a dictionary of actions
base_env = FarmEnv()
# Out:
# Creating the base Multi-Agent environment...
# Fetching real weather data for Lat: 30.901, Long: 75.8573 from Open-Meteo...
# Sucessfully fetched and processed real weather data from Open-Meteo.

# %%
print("Applying the Action Wrapper...")
# 2. Wrap the complex environment to make it look simple to the agent
# The PPO agent will only interact with this wrapped_env
wrapped_env = MultiAgentActionWrapper(base_env)

print("Environment is ready for MARL training.")
# Out:
# Applying the Action Wrapper...
# Environment is ready for MARL training.

# %%
model_marl = PPO(
    "MlpPolicy",
    wrapped_env,
    verbose=1,
    tensorboard_log=logs_dir # Tell the model where to save the live logs
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
checkpoint_callback = CheckpointCallback(
  save_freq=50000,
  save_path=os.path.join(logs_dir, 'checkpoints'),
  name_prefix="marl_model"
)

# %%
print(f"Starting powerful MARL training for {TRAINING_STEPS} timesteps...")
print("To view live training graphs, open a new terminal, activate your environment,")
print("navigate to the project folder, and run:")
print(f"tensorboard --logdir {os.path.abspath(logs_dir)}")

# Start the long training process
model_marl.learn(
    total_timesteps=TRAINING_STEPS,
    tb_log_name="PPO_MARL_SuperAgent", # A specific name for this training run
    callback=checkpoint_callback
)
# Out:
# Starting powerful MARL training for 1000000 timesteps...
# To view live training graphs, open a new terminal, activate your environment,
# navigate to the project folder, and run:
# tensorboard --logdir /Users/aadarshraj/Documents/ai_project/digital_twin_farm/logs/marl_logs
# Logging to ../logs/marl_logs/PPO_MARL_SuperAgent_13
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | 942      |
# | time/              |          |
# |    fps             | 5170     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 906          |
# | time/                   |              |
# |    fps                  | 3598         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0031017647 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.000596     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.08e+04     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 8.7e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 934          |
# | time/                   |              |
# |    fps                  | 3420         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046890173 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.00179      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.28e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 7.69e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 926         |
# | time/                   |             |
# |    fps                  | 3340        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.002364046 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.000602    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.9e+04     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 9.74e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 901          |
# | time/                   |              |
# |    fps                  | 3306         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0028223528 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.000312     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.72e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 7.88e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 927          |
# | time/                   |              |
# |    fps                  | 3273         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0011558864 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.000328     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.85e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00089     |
# |    value_loss           | 5.97e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 944         |
# | time/                   |             |
# |    fps                  | 3257        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.000982542 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.000267    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000731   |
# |    value_loss           | 9.64e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 949          |
# | time/                   |              |
# |    fps                  | 3248         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0035311598 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.000274     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 9.37e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 966          |
# | time/                   |              |
# |    fps                  | 3237         |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0043821996 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.000366     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.01e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 7.99e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 958          |
# | time/                   |              |
# |    fps                  | 3232         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0026379668 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.00203      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.49e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 7.84e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 948         |
# | time/                   |             |
# |    fps                  | 3227        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002568115 |
# |    clip_fraction        | 0.00107     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.00258     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.75e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 7.87e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 929         |
# | time/                   |             |
# |    fps                  | 3223        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006048174 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.00434     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 7.87e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 912          |
# | time/                   |              |
# |    fps                  | 3221         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0035832175 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.00528      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.72e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 7.37e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 904         |
# | time/                   |             |
# |    fps                  | 3218        |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004338667 |
# |    clip_fraction        | 0.000586    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.00891     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.21e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 5.56e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 905         |
# | time/                   |             |
# |    fps                  | 3216        |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003836961 |
# |    clip_fraction        | 0.000537    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.0133      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+04     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 6.97e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 895          |
# | time/                   |              |
# |    fps                  | 3215         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0014111702 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.0172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+04      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 7.01e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 898          |
# | time/                   |              |
# |    fps                  | 3214         |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0049390886 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.0191       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.31e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 6.51e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 917        |
# | time/                   |            |
# |    fps                  | 3213       |
# |    iterations           | 18         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00604205 |
# |    clip_fraction        | 0.000977   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | 0.0214     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.81e+04   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00448   |
# |    value_loss           | 6.24e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 910          |
# | time/                   |              |
# |    fps                  | 3213         |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0032567198 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.0279       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.67e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 7.32e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 915          |
# | time/                   |              |
# |    fps                  | 3213         |
# |    iterations           | 20           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0045260508 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.0359       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 6e+04        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 916          |
# | time/                   |              |
# |    fps                  | 3191         |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0073656994 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.0453       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+04      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 5.7e+04      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 90        |
# |    ep_rew_mean          | 914       |
# | time/                   |           |
# |    fps                  | 3191      |
# |    iterations           | 22        |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0055542 |
# |    clip_fraction        | 0.0103    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.13     |
# |    explained_variance   | 0.0494    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.56e+04  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.00353  |
# |    value_loss           | 5.97e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 927         |
# | time/                   |             |
# |    fps                  | 3191        |
# |    iterations           | 23          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003141363 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.0544      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59e+04    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00135    |
# |    value_loss           | 6.27e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 947          |
# | time/                   |              |
# |    fps                  | 3189         |
# |    iterations           | 24           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0045783725 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.0591       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.75e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 6.58e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 936         |
# | time/                   |             |
# |    fps                  | 3188        |
# |    iterations           | 25          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011085479 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.0581      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.35e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0046     |
# |    value_loss           | 7.45e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 936          |
# | time/                   |              |
# |    fps                  | 3189         |
# |    iterations           | 26           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0075617265 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.0741       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 5.26e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 947         |
# | time/                   |             |
# |    fps                  | 3190        |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005920864 |
# |    clip_fraction        | 0.000342    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.0832      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 5.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 945         |
# | time/                   |             |
# |    fps                  | 3189        |
# |    iterations           | 28          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008238288 |
# |    clip_fraction        | 0.00684     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.0729      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.11e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 6.69e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 954         |
# | time/                   |             |
# |    fps                  | 3188        |
# |    iterations           | 29          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.003413634 |
# |    clip_fraction        | 0.00122     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.0799      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+04     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 6.67e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 950          |
# | time/                   |              |
# |    fps                  | 3187         |
# |    iterations           | 30           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0052327286 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.0898       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+04      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 5.75e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 923          |
# | time/                   |              |
# |    fps                  | 3188         |
# |    iterations           | 31           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0046694274 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 4.73e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 934         |
# | time/                   |             |
# |    fps                  | 3184        |
# |    iterations           | 32          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007932702 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 4.65e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 910         |
# | time/                   |             |
# |    fps                  | 3184        |
# |    iterations           | 33          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004929827 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.4e+04     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 6.09e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 925          |
# | time/                   |              |
# |    fps                  | 3182         |
# |    iterations           | 34           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0031613484 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+04     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 3.92e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 950          |
# | time/                   |              |
# |    fps                  | 3180         |
# |    iterations           | 35           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0028140042 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 6.33e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 924          |
# | time/                   |              |
# |    fps                  | 3181         |
# |    iterations           | 36           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0033058038 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 5.04e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 931        |
# | time/                   |            |
# |    fps                  | 3182       |
# |    iterations           | 37         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00367294 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.12      |
# |    explained_variance   | 0.153      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.33e+04   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00244   |
# |    value_loss           | 4.22e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 909          |
# | time/                   |              |
# |    fps                  | 3183         |
# |    iterations           | 38           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0072156293 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5e+04      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 4.87e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 901         |
# | time/                   |             |
# |    fps                  | 3183        |
# |    iterations           | 39          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012036946 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 3.57e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 913         |
# | time/                   |             |
# |    fps                  | 3183        |
# |    iterations           | 40          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009229988 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+04     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 4.97e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 3184         |
# |    iterations           | 41           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0049170055 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.17e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 4.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 878         |
# | time/                   |             |
# |    fps                  | 3184        |
# |    iterations           | 42          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010431038 |
# |    clip_fraction        | 0.00264     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 2.99e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 880          |
# | time/                   |              |
# |    fps                  | 3184         |
# |    iterations           | 43           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0012340522 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76e+04     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000528    |
# |    value_loss           | 3.3e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 885          |
# | time/                   |              |
# |    fps                  | 3184         |
# |    iterations           | 44           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0038180377 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.18e+04     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 4.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 890          |
# | time/                   |              |
# |    fps                  | 3185         |
# |    iterations           | 45           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0021265135 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.99        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 4.25e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 893         |
# | time/                   |             |
# |    fps                  | 3185        |
# |    iterations           | 46          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011334671 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 3.55e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 882         |
# | time/                   |             |
# |    fps                  | 3185        |
# |    iterations           | 47          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009308821 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.08e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 3e+04       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 890          |
# | time/                   |              |
# |    fps                  | 3186         |
# |    iterations           | 48           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0056518456 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 3.13e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 879         |
# | time/                   |             |
# |    fps                  | 3186        |
# |    iterations           | 49          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004522852 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 4.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 905         |
# | time/                   |             |
# |    fps                  | 3186        |
# |    iterations           | 50          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.002719121 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000568   |
# |    value_loss           | 3.26e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 929         |
# | time/                   |             |
# |    fps                  | 3186        |
# |    iterations           | 51          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009998867 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.89e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 3.58e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 945         |
# | time/                   |             |
# |    fps                  | 3186        |
# |    iterations           | 52          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009694269 |
# |    clip_fraction        | 0.0062      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 4.21e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 937          |
# | time/                   |              |
# |    fps                  | 3186         |
# |    iterations           | 53           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0060334513 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68e+04     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 3.75e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 925         |
# | time/                   |             |
# |    fps                  | 3186        |
# |    iterations           | 54          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.007054718 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+04     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 3.34e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# ...
# |    iterations           | 472           |
# |    time_elapsed         | 1606          |
# |    total_timesteps      | 966656        |
# | train/                  |               |
# |    approx_kl            | 0.00079985557 |
# |    clip_fraction        | 0.00854       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.266        |
# |    explained_variance   | 0.967         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 960           |
# |    n_updates            | 4710          |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 7.22e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.37e+03     |
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 473          |
# |    time_elapsed         | 1607         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0016449237 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 521          |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 4.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.41e+03     |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 474          |
# |    time_elapsed         | 1608         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0012801095 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.26        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.24e+03     |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 5e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.45e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 475          |
# |    time_elapsed         | 1609         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0013866167 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.01e+03     |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.000314    |
# |    value_loss           | 6.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 1.47e+03    |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 476         |
# |    time_elapsed         | 1610        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.000709209 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.72e+03    |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 4.41e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.47e+03     |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 477          |
# |    time_elapsed         | 1611         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0004798438 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 579          |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | 0.000166     |
# |    value_loss           | 7.56e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 1.45e+03    |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 478         |
# |    time_elapsed         | 1612        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.001511256 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 939         |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 2.58e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.39e+03     |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 479          |
# |    time_elapsed         | 1613         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0013796964 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12e+03     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 2.24e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 1.42e+03      |
# | time/                   |               |
# |    fps                  | 608           |
# |    iterations           | 480           |
# |    time_elapsed         | 1614          |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 0.00045037104 |
# |    clip_fraction        | 0.00215       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.19         |
# |    explained_variance   | 0.989         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 487           |
# |    n_updates            | 4790          |
# |    policy_gradient_loss | -0.000449     |
# |    value_loss           | 1.46e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.38e+03     |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 481          |
# |    time_elapsed         | 1615         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0006937146 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 997          |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 3.83e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.45e+03     |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 482          |
# |    time_elapsed         | 1616         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0011091181 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+03     |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | -0.000641    |
# |    value_loss           | 3.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 1.53e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 483         |
# |    time_elapsed         | 1617        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.001293479 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.268      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+03    |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 1.49e+03   |
# | time/                   |            |
# |    fps                  | 612        |
# |    iterations           | 484        |
# |    time_elapsed         | 1618       |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.00167844 |
# |    clip_fraction        | 0.0302     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.234     |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06e+04   |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | -0.00294   |
# |    value_loss           | 6.37e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.54e+03     |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 485          |
# |    time_elapsed         | 1619         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0012565267 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.28e+03     |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 2.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.57e+03     |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 486          |
# |    time_elapsed         | 1620         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0007856402 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.215       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.53e+03     |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00032     |
# |    value_loss           | 7.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 1.54e+03     |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 487          |
# |    time_elapsed         | 1621         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0007507057 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.191       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.46e+03     |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.000666    |
# |    value_loss           | 6.54e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 1.56e+03      |
# | time/                   |               |
# |    fps                  | 615           |
# |    iterations           | 488           |
# |    time_elapsed         | 1622          |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 0.00030067013 |
# |    clip_fraction        | 0.00293       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.208        |
# |    explained_variance   | 0.982         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+03      |
# |    n_updates            | 4870          |
# |    policy_gradient_loss | -0.000646     |
# |    value_loss           | 4.12e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90            |
# |    ep_rew_mean          | 1.59e+03      |
# | time/                   |               |
# |    fps                  | 616           |
# |    iterations           | 489           |
# |    time_elapsed         | 1623          |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 0.00058785354 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.19         |
# |    explained_variance   | 0.986         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.58e+03      |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -0.000493     |
# |    value_loss           | 3.41e+03      |
# -------------------------------------------

# %%
final_model_path = os.path.join(models_dir, MODEL_NAME)
model_marl.save(final_model_path)

print(f"\n--- MARL Training Complete! ---")
print(f"Super-Agent model saved at: {final_model_path}")
# Out:
# --- MARL Training Complete! ---
# Super-Agent model saved at: ../models/ppo_marl_super_agent.zip
