# %%
import sys
import os
sys.path.append("../")

# %%
from simulation.farm_env import FarmEnv
from stable_baselines3 import PPO

# %%
models_dir = "../models"
os.makedirs(models_dir, exist_ok=True)

# %%
env = FarmEnv()
env.reset()
# Out:
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Farm Environment Ready
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# (array([ 0.5     ,  0.      , 33.540718], dtype=float32), {})

# %%
model_v2 = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
Training_Steps = 1000000
model_v2.learn(total_timesteps=Training_Steps)
# Out:
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# Crop Seed Ready: Wheat
# Soil Completed: Alluvial Starting Moisture: 50.0%
# ...

# %%
model_v2_path = os.path.join(models_dir, "ppo_wheat_model_main_final.zip")
model_v2.save(model_v2_path)
print(f"\nTraining complete new V4 model saved at: {model_v2_path}")
# Out:
# Training complete new V4 model saved at: ../models/ppo_wheat_model_main_final.zip
