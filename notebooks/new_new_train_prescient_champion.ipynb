# %%
# notebooks/train_ultimate_champion.ipynb

import sys
import os
sys.path.append('../')

# %%
from simulation.farm_env import FarmEnv
from simulation.env_wrapper import MultiAgentActionWrapper
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# %%
#### Configuration: UNCOMMENT THE CROP YOU WANT TO TRAIN ---

# === Option 1: WHEAT in Punjab ===
CROP_TYPE = "Wheat"
LATITUDE = 30.9010 # Ludhiana, Punjab
LONGITUDE = 75.8573
TRAINING_STEPS = 1000000

# === Option 2: RICE in Bihar ===
# CROP_TYPE = "Rice"
# LATITUDE = 24.7500 # Aurangabad, Bihar
# LONGITUDE = 84.3700
# TRAINING_STEPS = 3000000

# === Option 3: RICE in West Bengal ===
# CROP_TYPE = "Rice"
# LATITUDE = 22.5726 # Kolkata, West Bengal
# LONGITUDE = 88.3639
# TRAINING_STEPS = 3000000

# === Option 4: SUGARCANE in Uttar Pradesh ===
# CROP_TYPE = "Sugarcane"
# LATITUDE = 26.8467 # Lucknow, UP
# LONGITUDE = 80.9462
# TRAINING_STEPS = 5000000 # Sugarcane has a much longer season, needs more training

# %%
#### Dynamic Naming based on selected crop ---
MODEL_NAME = f"one_million_ppo_ULTIMATE_CHAMPION_{CROP_TYPE.upper()}.zip"
models_dir = "../models"
logs_dir = f"../logs/one_million_ultimate_champion_{CROP_TYPE.lower()}_logs/"
os.makedirs(models_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)


# --- 2. Environment Setup ---
print(f"--- Creating ULTIMATE environment for CROP: {CROP_TYPE} at LOC: ({LATITUDE}, {LONGITUDE}) ---")
# Out:
# --- Creating ULTIMATE environment for CROP: Wheat at LOC: (30.901, 75.8573) ---

# %%
# Define a function to create our most advanced environment
def make_env():
    env = FarmEnv(
        crop_type=CROP_TYPE,
        latitude=LATITUDE,
        longitude=LONGITUDE
    ) 
    env = MultiAgentActionWrapper(env)
    return env

# Create the wrapped environment
wrapped_env = make_env()
print("Environment ready.")
# Out:
# --- Loading ADVANCED Weather Forecaster Ensemble for LUDHIANA ---
# Loaded advanced model 1/5 for ludhiana successfully.
# Loaded advanced model 2/5 for ludhiana successfully.
# Loaded advanced model 3/5 for ludhiana successfully.
# Loaded advanced model 4/5 for ludhiana successfully.
# Loaded advanced model 5/5 for ludhiana successfully.
# Advanced stochastic weather forecaster for LUDHIANA loaded and ready.
# Fetching ADVANCED weather data for Lat: 30.901, Long: 75.8573 from Open-Meteo...
# Successfully fetched and processed advanced weather data.
# Environment ready.

# %%
#### 3. Model Definition with a More Powerful Brain ---

# A large neural network to handle the 16 complex observations
policy_kwargs = dict(net_arch=dict(pi=[256, 256, 128], vf=[256, 256, 128]))

model = PPO(
    "MlpPolicy",
    wrapped_env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=logs_dir,
    learning_rate=0.0001,
    n_steps=4096,
    batch_size=128,
    gamma=0.995, # Higher gamma for very long-term rewards
    gae_lambda=0.95
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
#### 4. Training ---

# Set up a callback to save the model periodically during the long run
checkpoint_callback = CheckpointCallback(
  save_freq=100000,
  save_path=os.path.join(logs_dir, 'checkpoints'),
  name_prefix=f"{CROP_TYPE.lower()}_champion"
)

# %%
print(f"\n--- Starting ULTIMATE CHAMPION training for {CROP_TYPE} ---")
print(f"Total timesteps: {TRAINING_STEPS}")
print(f"To view live training graphs, open a new terminal, activate your environment,")
print(f"navigate to the project folder, and run:")
print(f"tensorboard --logdir {os.path.abspath(logs_dir)}")
# Out:
# --- Starting ULTIMATE CHAMPION training for Wheat ---
# Total timesteps: 1000000
# To view live training graphs, open a new terminal, activate your environment,
# navigate to the project folder, and run:
# tensorboard --logdir /Users/aadarshraj/Documents/ai_project/digital_twin_farm/logs/one_million_ultimate_champion_wheat_logs

# %%
# Start the training process
model.learn(
    total_timesteps=TRAINING_STEPS,
    tb_log_name=f"PPO_Ultimate_Champion_{CROP_TYPE}",
    callback=checkpoint_callback
)


# --- 5. Save the Final Model ---
final_model_path = os.path.join(models_dir, MODEL_NAME)
model.save(final_model_path)

print(f"\n--- ULTIMATE CHAMPION Training Complete! ---")
print(f"The definitive model for {CROP_TYPE} is saved at: {final_model_path}")
# Out:
# Logging to ../logs/one_million_ultimate_champion_wheat_logs/PPO_Ultimate_Champion_Wheat_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | 7.75     |
# | time/              |          |
# |    fps             | 89       |
# |    iterations      | 1        |
# |    time_elapsed    | 45       |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.46        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 2           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011870669 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.0597      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.254       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.998       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.93        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 3           |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012163584 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.361       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.624       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.79        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 4           |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013888687 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.177       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.476       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.99        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 5           |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013914725 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.172       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.451       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.03        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 6           |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012786517 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.24        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.463       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.83        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 7           |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014260488 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.194       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.572       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.78        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 8           |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012904042 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.105       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.77        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 9           |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011979661 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.197       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.312       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.67        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 10          |
# |    time_elapsed         | 435         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012465317 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.238       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.405       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.76        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 11          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011381137 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.232       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.92        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 12          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012799777 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.306       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.327       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.78        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 13          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013050516 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.165       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.326       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.07        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 14          |
# |    time_elapsed         | 607         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011448583 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0599      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.273       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.39        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 15          |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011723999 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.129       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.284       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.28        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 16          |
# |    time_elapsed         | 692         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011614074 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0926      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.78        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 17          |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010972228 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0714      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.247       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 90        |
# |    ep_rew_mean          | 8.88      |
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 18        |
# |    time_elapsed         | 778       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0114002 |
# |    clip_fraction        | 0.111     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.48     |
# |    explained_variance   | 0.497     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 0.152     |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.0117   |
# |    value_loss           | 0.263     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.88        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 19          |
# |    time_elapsed         | 823         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011819968 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0235      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.8         |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 20          |
# |    time_elapsed         | 865         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012435706 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0616      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.97        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 21          |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.014179799 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0763      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.166       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.67        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 22          |
# |    time_elapsed         | 949         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009608952 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0505      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 0.127       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 8.92         |
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 23           |
# |    time_elapsed         | 1260         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0097189825 |
# |    clip_fraction        | 0.0908       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.37        |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0401       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.335        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 8.89         |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 24           |
# |    time_elapsed         | 1303         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0094420705 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.14         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.91        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 25          |
# |    time_elapsed         | 1346        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010489513 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0464      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.05        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 26          |
# |    time_elapsed         | 1391        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012190481 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0212      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.115       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.08        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 27          |
# |    time_elapsed         | 1443        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.009382268 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0866      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00979    |
# |    value_loss           | 0.152       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.99        |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 28          |
# |    time_elapsed         | 1486        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012731221 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0585      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.12        |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 29          |
# |    time_elapsed         | 1535        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.011392431 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0246      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.91        |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 30          |
# |    time_elapsed         | 1579        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.010996791 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0523      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.125       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 8.79       |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 31         |
# |    time_elapsed         | 1622       |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.01064517 |
# |    clip_fraction        | 0.0932     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.759      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0193     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 0.111      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 8.71         |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 32           |
# |    time_elapsed         | 1666         |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0081128385 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.787        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00322      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00981     |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.94        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 33          |
# |    time_elapsed         | 1716        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.009418203 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0039     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.0906      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 34          |
# |    time_elapsed         | 1763        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.009689566 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.106       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.126       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.99        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 35          |
# |    time_elapsed         | 1810        |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.010867647 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0131      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.0995      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.04        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 36          |
# |    time_elapsed         | 1856        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.010942521 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0305      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.22        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 37          |
# |    time_elapsed         | 1902        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.011042228 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0451      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.0991      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.29        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 38          |
# |    time_elapsed         | 1948        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.009818438 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0412      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.19        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 39          |
# |    time_elapsed         | 1995        |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.009133631 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.016       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.12        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 40          |
# |    time_elapsed         | 2041        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009410836 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00222    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.0728      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.28        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 41          |
# |    time_elapsed         | 2088        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.009928414 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0405      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.25        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 42          |
# |    time_elapsed         | 2134        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.011039538 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0146      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.0898      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.1         |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 43          |
# |    time_elapsed         | 2181        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.011285725 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0178      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.0934      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.12        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 44          |
# |    time_elapsed         | 2227        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.010515682 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0147      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00999    |
# |    value_loss           | 0.0614      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 9.2          |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 45           |
# |    time_elapsed         | 2275         |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0112200165 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00671      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.0428       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.03        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 46          |
# |    time_elapsed         | 2320        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010347678 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0255     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.0397      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.08        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 47          |
# |    time_elapsed         | 2363        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.011439074 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00296    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 9.02       |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 48         |
# |    time_elapsed         | 2408       |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.00908858 |
# |    clip_fraction        | 0.0702     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0102    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 0.0503     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.17        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 49          |
# |    time_elapsed         | 2454        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.009660231 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00247     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.0703      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.05        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 50          |
# |    time_elapsed         | 2500        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.008808289 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00967     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.0221      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.03        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 51          |
# |    time_elapsed         | 2547        |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.008383096 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0146     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 0.0448      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 8.95         |
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 52           |
# |    time_elapsed         | 2593         |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0069798143 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0168      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.0273       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.99        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 53          |
# |    time_elapsed         | 2637        |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.009098383 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00404     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.0194      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 9.03        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 54          |
# |    time_elapsed         | 2682        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.007399083 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0204      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00877    |
# |    value_loss           | 0.0439      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 8.97        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 55          |
# |    time_elapsed         | 2727        |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.010280324 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00827    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0112     |
# ...
# |    fps                  | 36           |
# |    iterations           | 228          |
# |    time_elapsed         | 25398        |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0036983914 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0684       |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00449     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 229         |
# |    time_elapsed         | 25446       |
# |    total_timesteps      | 937984      |
# | train/                  |             |
# |    approx_kl            | 0.005087048 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0668      |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 230         |
# |    time_elapsed         | 25488       |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.004486089 |
# |    clip_fraction        | 0.0376      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0366      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 0.153       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 231          |
# |    time_elapsed         | 25530        |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0035012683 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.854       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0485       |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00437     |
# |    value_loss           | 0.165        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 232          |
# |    time_elapsed         | 25573        |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0048653707 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0823       |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 0.147        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 233          |
# |    time_elapsed         | 25616        |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0041438397 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.104        |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.0062      |
# |    value_loss           | 0.174        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 234          |
# |    time_elapsed         | 25662        |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0057110796 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.107        |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00694     |
# |    value_loss           | 0.178        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 235         |
# |    time_elapsed         | 25712       |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.004669601 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0481      |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.0046     |
# |    value_loss           | 0.173       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 16.1       |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 236        |
# |    time_elapsed         | 25759      |
# |    total_timesteps      | 966656     |
# | train/                  |            |
# |    approx_kl            | 0.00700354 |
# |    clip_fraction        | 0.0656     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.894     |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0504     |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | -0.00855   |
# |    value_loss           | 0.151      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 237         |
# |    time_elapsed         | 25804       |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.005833188 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0715      |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 0.166       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 238          |
# |    time_elapsed         | 25848        |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0076145707 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0604       |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.00744     |
# |    value_loss           | 0.157        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 239         |
# |    time_elapsed         | 25891       |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.005913045 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.119       |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 0.195       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 240          |
# |    time_elapsed         | 25935        |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0045968676 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0619       |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 0.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 241         |
# |    time_elapsed         | 25979       |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.005076496 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0894      |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00672    |
# |    value_loss           | 0.209       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 242          |
# |    time_elapsed         | 26023        |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0045892047 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0803       |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 0.163        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 243          |
# |    time_elapsed         | 26065        |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0056476207 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0475       |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 0.152        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 244         |
# |    time_elapsed         | 26106       |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.008082067 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0964      |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 0.191       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 16.2         |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 245          |
# |    time_elapsed         | 26149        |
# |    total_timesteps      | 1003520      |
# | train/                  |              |
# |    approx_kl            | 0.0045053517 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0534       |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.00641     |
# |    value_loss           | 0.144        |
# ------------------------------------------
#
# --- ULTIMATE CHAMPION Training Complete! ---
# The definitive model for Wheat is saved at: ../models/one_million_ppo_ULTIMATE_CHAMPION_WHEAT.zip
